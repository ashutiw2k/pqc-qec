# %%
import math
import torch
import torch.nn as nn
import torch.nn.functional as F

from torch.utils.data import DataLoader, Dataset

import numpy as np
import os
from typing import List, Tuple, Optional, Dict, Any, Sequence
from itertools import permutations, combinations
from tqdm import tqdm
import time
import json

# %%
import sys
sys.path.append('../')

# %% [markdown]
# # Vocabulary and Tokenizer

# %%
class QuantumCircuitTokenizer:
    """
    A tokenizer to convert quantum circuits into integer sequences.

    This version is finalized for the QueryAngleTransformer, handles the
    (gate, qubits, params) input format, and includes methods to save and
    load the vocabulary.
    """
    def __init__(
        self,
        max_qubits: int,
        gates_config: Optional[Dict] = None,
        vocab: Optional[Tuple[Dict, Dict]] = None
    ):
        """
        Initializes the tokenizer. Can either build a vocabulary from scratch
        or load a pre-built one.
        """
        self.max_qubits = max_qubits

        if vocab:
            # Load from a pre-built vocabulary
            self.token2id, self.id2token = vocab
            self.gates_config = gates_config if gates_config else self._get_default_config()
        else:
            # Build vocabulary from scratch
            self.gates_config = gates_config if gates_config else self._get_default_config()
            self.token2id, self.id2token = self._build_vocab()

        # Cache special token IDs for faster access
        self.pad_token_id = self.token2id.get(('[PAD]', ()), 0)
        self.unk_token_id = self.token2id.get(('[UNK]', ()), 1)

    def _get_default_config(self) -> Dict:
        """Provides the default gate configuration, excluding [CLS]."""
        return {
            'special_tokens': ['[PAD]', '[UNK]'],
            'gates_1q': ['x', 'z', 'h', 'rx', 'rz'],
            'gates_2q': {
                'cx': {'ordered': True},
                'cz': {'ordered': False}
            }
        }

    def _build_vocab(self) -> Tuple[Dict, Dict]:
        """Builds the vocabulary from the gate configuration."""
        token2id, id2token = {}, {}
        next_id = 0
        for sp in self.gates_config['special_tokens']:
            token = (sp, ())
            token2id[token], id2token[next_id] = next_id, token
            next_id += 1
        for gate in self.gates_config['gates_1q']:
            for q in range(self.max_qubits):
                token = (gate, (q,))
                token2id[token], id2token[next_id] = next_id, token
                next_id += 1
        for gate, props in self.gates_config['gates_2q'].items():
            pairs = permutations(range(self.max_qubits), 2) if props['ordered'] else combinations(range(self.max_qubits), 2)
            for qubits in pairs:
                token = (gate, tuple(qubits))
                token2id[token], id2token[next_id] = next_id, token
                next_id += 1
        return token2id, id2token

    @property
    def vocab_size(self) -> int:
        return len(self.token2id)

    def encode(
        self,
        circuit: Sequence[Tuple[str, Sequence[int], Any]],
        pad_to_len: Optional[int] = None,
        return_tensors: Optional[str] = None
    ) -> Dict[str, Any]:
        """
        Encodes a circuit into a sequence of token IDs and an attention mask.
        Assumes circuit format is (gate, qubits, params).
        """
        ids: List[int] = []
        gate_properties = self.gates_config['gates_2q']

        # This loop correctly unpacks the (gate, qubits, params) tuple
        for gate, qlist, _ in circuit:
            if any(q >= self.max_qubits for q in qlist):
                raise ValueError(f"Qubit index in {qlist} exceeds max_qubits ({self.max_qubits})")

            q_tuple = tuple(qlist)
            if len(q_tuple) == 2 and not gate_properties.get(gate, {}).get('ordered', True):
                q_tuple = tuple(sorted(q_tuple))

            token = (gate, q_tuple)
            ids.append(self.token2id.get(token, self.unk_token_id))

        attention_mask = [1] * len(ids)

        if pad_to_len and len(ids) < pad_to_len:
            pad_needed = pad_to_len - len(ids)
            ids.extend([self.pad_token_id] * pad_needed)
            attention_mask.extend([0] * pad_needed)

        if return_tensors == 'pt':
            return {
                'input_ids': torch.tensor(ids, dtype=torch.long),
                # The key is 'attention_mask' to match the model's forward pass
                'attention_mask': torch.tensor(attention_mask, dtype=torch.bool)
            }

        return {'input_ids': ids, 'attention_mask': [bool(m) for m in attention_mask]}

    def decode(self, ids: Sequence[int], drop_special: bool = True) -> List[Tuple[str, List[int]]]:
        """Decodes a sequence of IDs back into a circuit representation."""
        out = []
        special_tokens = set(self.gates_config['special_tokens'])
        for i in ids:
            if isinstance(i, torch.Tensor): i = i.item()
            gate, q_tuple = self.id2token.get(i, ('[UNK]', ()))
            if drop_special and gate in special_tokens:
                continue
            out.append((gate, list(q_tuple), []))
        return out

    def save_vocab(self, vocab_path: str):
        """Saves the vocabulary (token2id map) to a JSON file."""
        # Convert tuple keys to strings for JSON compatibility
        saveable_token2id = {str(k): v for k, v in self.token2id.items()}
        with open(vocab_path, 'w') as f:
            json.dump(saveable_token2id, f)
        print(f"Vocabulary of size {self.vocab_size} saved to {vocab_path}")

    @classmethod
    def from_file(cls, vocab_path: str, max_qubits: int):
        """Loads a tokenizer from a saved vocabulary file."""
        with open(vocab_path, 'r') as f:
            loaded_token2id_str_keys = json.load(f)
            # `eval` is used to convert stringified tuples back to tuples
            token2id = {eval(k): v for k, v in loaded_token2id_str_keys.items()}
            id2token = {v: k for k, v in token2id.items()}
        print(f"Vocabulary of size {len(token2id)} loaded from {vocab_path}")
        return cls(max_qubits=max_qubits, vocab=(token2id, id2token))

    def get_token_id(self, token: Tuple[str, Tuple[int, int]]) -> int:
        """Returns the token ID for a given (gate, qubits) tuple."""
        return self.token2id.get(token, self.unk_token_id)

    def get_token(self, token_id: int) -> Tuple[str, Tuple[int, int]]:
        """Returns the (gate, qubits) tuple for a given token ID."""
        return self.id2token.get(token_id, ('[UNK]', ()))

class QuantumCircuitDataset(Dataset):
    def __init__(self, circuits_data: List[Sequence[Tuple[str, Sequence[int], Sequence[float]]]], tokenizer: QuantumCircuitTokenizer):
        self.circuits_data = circuits_data
        self.tokenizer = tokenizer

    def __len__(self):
        return len(self.circuits_data)

    def __getitem__(self, idx):
        circuit, pqc_params = self.circuits_data[idx]
        # Encode the circuit and return tensors directly
        encoding = self.tokenizer.encode(circuit, return_tensors='pt')
        return encoding, pqc_params

# %% [markdown]
# # Transformer Model Architecture

# %%
# --------------------
# Step 1: Positional Encoding Module
# --------------------
class PositionalEncoding(nn.Module):
    def __init__(self, d_model, max_len=2048):
        super().__init__()
        pe = torch.zeros(max_len, d_model)
        position = torch.arange(0, max_len, dtype=torch.float).unsqueeze(1)
        div_term = torch.exp(torch.arange(0, d_model, 2).float() * (-math.log(10000.0) / d_model))
        pe[:, 0::2] = torch.sin(position * div_term)
        pe[:, 1::2] = torch.cos(position * div_term)
        pe = pe.unsqueeze(0)  # shape: [1, max_len, d_model]
        self.register_buffer('pe', pe)

    def forward(self, x):
        x = x + self.pe[:, :x.size(1)]
        return x

# --------------------
# Step 2: Transformer Encoder
# --------------------
class TransformerEncoder(nn.Module):
    def __init__(self, vocab_size, d_model, n_heads, d_ff, n_layers, max_len, pad_token_id):
        super().__init__()
        self.token_emb = nn.Embedding(vocab_size, d_model, padding_idx=pad_token_id)
        self.pos_enc = PositionalEncoding(d_model, max_len=max_len)
        
        # ✅ FIX: Use a ModuleList to hold the encoder layers
        self.layers = nn.ModuleList([
            nn.TransformerEncoderLayer(
                d_model=d_model, nhead=n_heads, dim_feedforward=d_ff, batch_first=True
            ) for _ in range(n_layers)
        ])
        
        self.norm = nn.LayerNorm(d_model)

    def forward(self, input_ids, attention_mask):
        x = self.token_emb(input_ids) * math.sqrt(self.token_emb.embedding_dim)
        x = self.pos_enc(x)
        src_key_padding_mask = (attention_mask == 0)
        
        # ✅ FIX: Apply each layer in a loop
        # This bypasses the unimplemented nested tensor optimization on MPS
        for layer in self.layers:
            x = layer(x, src_key_padding_mask=src_key_padding_mask)
            
        return self.norm(x)

# --------------------
# Step 3: Transformer Model with Mean Pooling
# --------------------
class MeanPoolingTransformer(nn.Module):
    def __init__(self, vocab_size, pad_token_id, output_shape, d_model=512,
                 num_model_heads=8, d_ff=2048,
                 num_encoder_layers=6, max_len=2048, dropout=0.1):
        super().__init__()
        self.output_shape = output_shape
        self.K, self.Q, self.P = output_shape
        self.num_params = self.K * self.Q * self.P

        self.encoder = TransformerEncoder(
            vocab_size, d_model, num_model_heads, d_ff, num_encoder_layers, max_len, pad_token_id
        )

        self.out_head = nn.Sequential(
            nn.LayerNorm(d_model),
            nn.Linear(d_model, d_ff),
            nn.GELU(),
            nn.Dropout(dropout),
            nn.Linear(d_ff, self.num_params)
        )

    def forward(self, input_ids, attention_mask):
        is_batched = input_ids.dim() == 2
        if not is_batched:
            input_ids = input_ids.unsqueeze(0)
            if attention_mask is not None:
                attention_mask = attention_mask.unsqueeze(0)

        B = input_ids.shape[0]

        # 1. Get the full encoder output for all tokens.
        #    Shape: [batch_size, sequence_length, d_model]
        encoder_output = self.encoder(input_ids, attention_mask)

        # --- ✅ 2. Perform Mean Pooling ---
        # To correctly calculate the mean, we must ignore padding tokens.
        
        # Expand the attention_mask to match the shape of the encoder output.
        mask_expanded = attention_mask.unsqueeze(-1).expand(encoder_output.size()).float()
        
        # Sum the embeddings of non-padded tokens.
        sum_embeddings = torch.sum(encoder_output * mask_expanded, 1)
        
        # Sum the mask to get the actual (non-padded) length of each sequence.
        # Add a small epsilon to avoid division by zero.
        sum_mask = torch.clamp(attention_mask.sum(1), min=1e-9)
        
        # Divide the sum of embeddings by the actual length to get the mean.
        # This is the single vector representation for the entire sequence.
        mean_pooled_embedding = sum_embeddings / sum_mask.unsqueeze(-1)
        # Shape: [batch_size, d_model]
        # ---------------------------------

        # 3. Pass this single vector through the output head.
        #    Shape: [batch_size, num_params]
        flat_output = self.out_head(mean_pooled_embedding)

        # 4. Reshape the flat output to your desired structured shape.
        #    Shape: [batch_size, K, Q, P]
        structured_output = flat_output.view(B, self.K, self.Q, self.P)

        if not is_batched:
            structured_output = structured_output.squeeze(0)

        return structured_output

# %% [markdown]
# # Loss Function/s

# %%
# --------------------
# Circular Loss Function
# --------------------
def angles_to_sin_cos(theta: torch.Tensor) -> torch.Tensor:
    """Convert angles to (sin, cos) representation."""
    return torch.stack([torch.sin(theta), torch.cos(theta)], dim=-1)

def sin_cos_to_angles(sin_cos: torch.Tensor) -> torch.Tensor:
    """
    Convert (sin, cos) representation back to angles in radians.

    Args:
        sin_cos: Tensor of shape (..., 2) where sin_cos[..., 0] = sin(θ), sin_cos[..., 1] = cos(θ)

    Returns:
        angles: Tensor of shape (...) in radians
    """
    sin_vals = sin_cos[..., 0]
    cos_vals = sin_cos[..., 1]
    angles = torch.atan2(sin_vals, cos_vals)  # returns in range (-π, π]
    return angles


def circular_loss(pred_sin_cos: torch.Tensor, target_sin_cos: torch.Tensor) -> torch.Tensor:
    """
    Computes circular loss: 1 - cos(Δθ) = 1 - dot(pred, target).
    Args:
        pred_sin_cos: [B, S, 2] predicted unit vectors
        target_sin_cos: [B, S, 2] target unit vectors
        mask: [B, S] binary mask for valid slots
    Returns:
        Scalar loss averaged over valid slots
    """
    dots = (pred_sin_cos * target_sin_cos).sum(dim=-1)  # [B, S]
    loss_per = 1.0 - dots
    
    loss = loss_per.mean()
    return loss

def circular_mae(pred_sin_cos: torch.Tensor, target_sin_cos: torch.Tensor) -> torch.Tensor:
    """
    Computes circular MAE: mean angular distance (radians) between predicted and target angles.
    """
    cos_delta = (pred_sin_cos * target_sin_cos).sum(dim=-1).clamp(-1.0, 1.0)
    angle_diff = torch.acos(cos_delta)
   
    mae = angle_diff.mean()
    
    return mae

def cosine_loss(pred_angles: torch.Tensor, target_angles: torch.Tensor) -> torch.Tensor:
    """
    Computes cosine loss between predicted and target angles.
    """
    cos_loss = 1 - torch.cos(pred_angles - target_angles)
    return cos_loss.mean()

# %% [markdown]
# # Training Loop

# %%
# # --------------------
# # Step 5: Training Loop
# # --------------------
# def train_step(model, batch, optimizer, scaler=None):
#     model.train()
#     input_ids = batch['input_ids']
#     attention_mask = batch['attention_mask']
#     slot_idx = batch['slot_idx']
#     slot_mask = batch['slot_mask']
#     target_sincos = batch['target_sincos']

#     optimizer.zero_grad(set_to_none=True)
#     with torch.cuda.amp.autocast(enabled=(scaler is not None)):
#         pred_sincos = model(input_ids, attention_mask, slot_idx, slot_mask)
#         loss = circular_loss(pred_sincos, target_sincos, slot_mask)
#         mae = circular_mae(pred_sincos, target_sincos, slot_mask)

#     if scaler:
#         scaler.scale(loss).backward()
#         scaler.unscale_(optimizer)
#         torch.nn.utils.clip_grad_norm_(model.parameters(), max_norm=1.0)
#         scaler.step(optimizer)
#         scaler.update()
#     else:
#         loss.backward()
#         torch.nn.utils.clip_grad_norm_(model.parameters(), max_norm=1.0)
#         optimizer.step()

#     return {'loss': float(loss.item()), 'circular_mae': float(mae.item())}

# %%
# =============================================================================
# 1. ROBUST TRAINING STEP FUNCTION
# =============================================================================
def training_step(
    model: nn.Module,
    batch: dict,
    optimizer: torch.optim.Optimizer,
    scheduler: torch.optim.lr_scheduler._LRScheduler, # Added scheduler
    device: torch.device,
) -> float:
    """
    A stable training step with gradient clipping and a learning rate scheduler.
    """
    model.train()

    encodings, target_angles = batch
    input_ids = encodings['input_ids'].to(device)
    attention_mask = encodings['attention_mask'].to(device)
    target_angles = target_angles.to(device)

    optimizer.zero_grad(set_to_none=True)
    
    # Use autocast for performance on compatible hardware (MPS or CUDA)
    with torch.amp.autocast(device_type=device.type, dtype=torch.bfloat16):
        predicted_params = model(input_ids, attention_mask=attention_mask)
        loss = cosine_loss(predicted_params, target_angles)

    # --- Backward Pass ---
    loss.backward()

    # --- CRUCIAL: GRADIENT CLIPPING ---
    # This must be done AFTER .backward() and BEFORE .step()
    # It prevents gradients from exploding and becoming NaN.
    torch.nn.utils.clip_grad_norm_(model.parameters(), 1.0)
    
    # --- Optimizer and Scheduler Step ---
    optimizer.step()
    scheduler.step() # The scheduler must be updated at each step

    return loss.item()

# =============================================================================
# 2. EVALUATION STEP FUNCTION (for validation)
# =============================================================================
def validation_step(
    model: nn.Module,
    batch: dict,
    device: torch.device
) -> float:
    """Performs a single evaluation step on a batch of validation data."""
    model.eval()
    encodings, target_angles = batch
    input_ids = encodings['input_ids'].to(device)
    attention_mask = encodings['attention_mask'].to(device)
    target_angles = target_angles.to(device)

    with torch.no_grad():
        # Use autocast here as well for consistency and performance
        # with torch.amp.autocast(device_type=device.type, dtype=torch.bfloat16):
        predicted_params = model(input_ids, attention_mask=attention_mask)
        loss = cosine_loss(predicted_params, target_angles)

    return loss.item()

# =============================================================================
# 3. MAIN TRAINING LOOP FUNCTION
# =============================================================================
def train_model(
    model: nn.Module,
    train_dataloader: DataLoader,
    val_dataloader: DataLoader,
    optimizer: torch.optim.Optimizer,
    scheduler: torch.optim.lr_scheduler._LRScheduler, # Added scheduler
    epochs: int,
    device: torch.device
):
    """
    The main training loop, now correctly using the scheduler.
    """
    model.to(device)
    epoch_train_losses, epoch_val_losses = [], []
    
    for epoch in range(epochs):
        start_time = time.time()
        
        # --- Training Phase ---
        train_loss = 0.0
        for batch in train_dataloader:
            # Pass the scheduler to the training step
            loss = training_step(model, 
                                 batch, 
                                 optimizer, 
                                 scheduler,
                                 device)
            train_loss += loss
        avg_train_loss = train_loss / len(train_dataloader)

        # --- Validation Phase ---
        val_loss = 0.0
        for batch in val_dataloader:
            loss = validation_step(model, batch, device)
            val_loss += loss
        avg_val_loss = val_loss / len(val_dataloader)

        end_time = time.time()
        epoch_duration = end_time - start_time
        
        # --- Print Epoch Summary ---
        current_lr = scheduler.get_last_lr()[0] # Log the LR to see it change
        print(f"Model {model._get_name()} | "
              f"Epoch {epoch + 1}/{epochs} | "
              f"Duration: {epoch_duration:.2f}s | "
              f"Train Loss: {avg_train_loss:.4f} | "
              f"Val Loss: {avg_val_loss:.4f} | "
              f"LR: {current_lr:.6f}"
            )

        epoch_train_losses.append(avg_train_loss)
        epoch_val_losses.append(avg_val_loss)

    return epoch_train_losses, epoch_val_losses

# %%
NUM_QUBITS = 5
NUM_GATES = 20 * 2 # Or 40, if needed.
GATE_BLOCKS = 10
PQC_GATES = ['rz', 'rx', 'rz']
DATA_DIR = "../json_data/5q_20g_10blk_data"

BATCH_SIZE = 16
VAL_STEP = 10
EPOCHS = 1000
LEARNING_RATE = 5e-5
WEIGHT_DECAY = 1e-2

D_MODEL = 32
NUM_MODEL_HEAD = 2
NUM_ENCODER_LAYERS = 2
NUM_DECODER_LAYERS = 2
DIM_FEEDFORWARD = 64
DROPOUT = 0.2

# %%
raw_data = []
for file in os.listdir(DATA_DIR):
    names = file.split('.')
    if file.endswith('.json') and names[0].isdigit() and len(names) == 2:
        with open(os.path.join(DATA_DIR, file), 'r') as f:
            file_data = json.load(f)
            raw_data.append(file_data)

len(raw_data)
# Out:
# 869

# %%
circuit_data = [(d['base_circuit_tokens'], torch.tensor(d['pqc_params'])) for d in raw_data]

qc_tokenizer = QuantumCircuitTokenizer(max_qubits=NUM_QUBITS)
qc_dataset = QuantumCircuitDataset(circuit_data, qc_tokenizer)

TRAIN_SIZE = int(0.7 * len(qc_dataset))
VAL_SIZE = int(0.1 * len(qc_dataset))
TEST_SIZE = len(qc_dataset) - TRAIN_SIZE - VAL_SIZE

qc_train_dataset, qc_val_dataset, qc_test_dataset = torch.utils.data.random_split(qc_dataset, [TRAIN_SIZE, VAL_SIZE, TEST_SIZE])
# qc_val_dataset = QuantumCircuitDataset(circuit_data[::VAL_STEP], qc_tokenizer)

qc_train_dataloader = DataLoader(qc_train_dataset, batch_size=BATCH_SIZE, shuffle=True)
qc_val_dataloader = DataLoader(qc_val_dataset, batch_size=BATCH_SIZE, shuffle=True)
qc_test_dataloader = DataLoader(qc_test_dataset, shuffle=True)

print(len(qc_train_dataset), len(qc_train_dataloader))
print(len(qc_val_dataset), len(qc_val_dataloader))
print(len(qc_test_dataset), len(qc_test_dataloader))
# Out:
# 608 38
# 86 6
# 175 175

# %%
device = torch.device("cuda" if torch.cuda.is_available() else ("mps" if torch.mps.is_available() else "cpu"))
# device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
print(f"Using device: {device}")

model = MeanPoolingTransformer(vocab_size=qc_tokenizer.vocab_size, pad_token_id=qc_tokenizer.pad_token_id,
                              output_shape=(NUM_GATES//GATE_BLOCKS, NUM_QUBITS,len(PQC_GATES)), # Output shape of (K,Q,P)
                              d_model=D_MODEL, num_model_heads=NUM_MODEL_HEAD,
                              num_encoder_layers=NUM_ENCODER_LAYERS,
                              d_ff=DIM_FEEDFORWARD, dropout=DROPOUT)

print(f"Model:\n{model}")

optimizer = torch.optim.AdamW(model.parameters(), lr=LEARNING_RATE, weight_decay=WEIGHT_DECAY)

# --- 3. Calculate Scheduler Parameters ---
# Get the number of training steps per epoch
STEPS_PER_EPOCH = len(qc_train_dataloader)

# Calculate the total number of training steps
TOTAL_STEPS = EPOCHS * STEPS_PER_EPOCH

# Set the number of warmup steps (e.g., for the first 5-10 epochs)
WARMUP_EPOCHS = 10
WARMUP_STEPS = WARMUP_EPOCHS * STEPS_PER_EPOCH

# --- 4. Create the Schedulers ---
# Create the linear warmup scheduler
warmup_scheduler = torch.optim.lr_scheduler.LinearLR(
    optimizer,
    start_factor=1e-6, # Start LR will be LEARNING_RATE * start_factor
    total_iters=WARMUP_STEPS
)

# Create the cosine decay scheduler
cosine_scheduler = torch.optim.lr_scheduler.CosineAnnealingLR(
    optimizer,
    T_max=TOTAL_STEPS - WARMUP_STEPS, # The number of steps for the decay phase
    eta_min= 5e-6
)

# --- 5. Chain the Schedulers Together ---
# This will apply the warmup scheduler first, followed by the cosine scheduler.
scheduler = torch.optim.lr_scheduler.ChainedScheduler(
    [warmup_scheduler, cosine_scheduler]
)
# Out:
# Using device: mps
# Model:
# MeanPoolingTransformer(
#   (encoder): TransformerEncoder(
#     (token_emb): Embedding(57, 32, padding_idx=0)
#     (pos_enc): PositionalEncoding()
#     (layers): ModuleList(
#       (0-1): 2 x TransformerEncoderLayer(
#         (self_attn): MultiheadAttention(
#           (out_proj): NonDynamicallyQuantizableLinear(in_features=32, out_features=32, bias=True)
#         )
#         (linear1): Linear(in_features=32, out_features=64, bias=True)
#         (dropout): Dropout(p=0.1, inplace=False)
#         (linear2): Linear(in_features=64, out_features=32, bias=True)
#         (norm1): LayerNorm((32,), eps=1e-05, elementwise_affine=True)
#         (norm2): LayerNorm((32,), eps=1e-05, elementwise_affine=True)
#         (dropout1): Dropout(p=0.1, inplace=False)
#         (dropout2): Dropout(p=0.1, inplace=False)
#       )
#     )
#     (norm): LayerNorm((32,), eps=1e-05, elementwise_affine=True)
#   )
#   (out_head): Sequential(
#     (0): LayerNorm((32,), eps=1e-05, elementwise_affine=True)
#     (1): Linear(in_features=32, out_features=64, bias=True)
#     (2): GELU(approximate='none')
#     (3): Dropout(p=0.2, inplace=False)
#     (4): Linear(in_features=64, out_features=60, bias=True)
#   )
# )

# %%
# --- 4. Start Training ---
train_losses, val_losses = train_model(
    model=model,
    train_dataloader=qc_train_dataloader,
    val_dataloader=qc_val_dataloader,
    optimizer=optimizer,
    scheduler=scheduler,  # Pass the scheduler here
    epochs=EPOCHS,
    device=device
)
# Out:
# Model MeanPoolingTransformer | Epoch 1/1000 | Duration: 1.07s | Train Loss: 0.9967 | Val Loss: 0.9905 | LR: 0.000005
# Model MeanPoolingTransformer | Epoch 2/1000 | Duration: 0.49s | Train Loss: 0.9970 | Val Loss: 0.9885 | LR: 0.000010
# Model MeanPoolingTransformer | Epoch 3/1000 | Duration: 0.48s | Train Loss: 0.9966 | Val Loss: 0.9827 | LR: 0.000015
# Model MeanPoolingTransformer | Epoch 4/1000 | Duration: 0.48s | Train Loss: 0.9962 | Val Loss: 0.9922 | LR: 0.000020
# Model MeanPoolingTransformer | Epoch 5/1000 | Duration: 0.48s | Train Loss: 0.9959 | Val Loss: 0.9864 | LR: 0.000025
# Model MeanPoolingTransformer | Epoch 6/1000 | Duration: 0.48s | Train Loss: 0.9960 | Val Loss: 0.9873 | LR: 0.000030
# Model MeanPoolingTransformer | Epoch 7/1000 | Duration: 0.48s | Train Loss: 0.9955 | Val Loss: 0.9753 | LR: 0.000035
# Model MeanPoolingTransformer | Epoch
| LR: 0.000005
# Model MeanPoolingTransformer | Epoch 985/1000 | Duration: 0.46s | Train Loss: 0.7891 | Val Loss: 0.9946 | LR: 0.000005
# Model MeanPoolingTransformer | Epoch 986/1000 | Duration: 0.47s | Train Loss: 0.7909 | Val Loss: 0.9930 | LR: 0.000005
# Model MeanPoolingTransformer | Epoch 987/1000 | Duration: 0.47s | Train Loss: 0.7923 | Val Loss: 0.9977 | LR: 0.000005
# Model MeanPoolingTransformer | Epoch 988/1000 | Duration: 0.48s | Train Loss: 0.7890 | Val Loss: 0.9894 | LR: 0.000005
# Model MeanPoolingTransformer | Epoch 989/1000 | Duration: 0.48s | Train Loss: 0.7864 | Val Loss: 0.9955 | LR: 0.000005
# Model MeanPoolingTransformer | Epoch 990/1000 | Duration: 0.48s | Train Loss: 0.7893 | Val Loss: 0.9978 | LR: 0.000005
# Model MeanPoolingTransformer | Epoch 991/1000 | Duration: 0.47s | Train Loss: 0.7906 | Val Loss: 0.9915 | LR: 0.000005
# Model MeanPoolingTransformer | Epoch 992/1000 | Duration: 0.47s | Train Loss: 0.7895 | Val Loss: 0.9987 | LR: 0.000005
# Model MeanPoolingTransformer | Epoch 993/1000 | Duration: 0.47s | Train Loss: 0.7948 | Val Loss: 0.9904 | LR: 0.000005
# Model MeanPoolingTransformer | Epoch 994/1000 | Duration: 0.47s | Train Loss: 0.7914 | Val Loss: 0.9891 | LR: 0.000005
# Model MeanPoolingTransformer | Epoch 995/1000 | Duration: 0.48s | Train Loss: 0.7914 | Val Loss: 0.9905 | LR: 0.000005
# Model MeanPoolingTransformer | Epoch 996/1000 | Duration: 0.48s | Train Loss: 0.7923 | Val Loss: 0.9916 | LR: 0.000005
# Model MeanPoolingTransformer | Epoch 997/1000 | Duration: 0.47s | Train Loss: 0.7880 | Val Loss: 0.9928 | LR: 0.000005
# Model MeanPoolingTransformer | Epoch 998/1000 | Duration: 0.47s | Train Loss: 0.7893 | Val Loss: 0.9900 | LR: 0.000005
# Model MeanPoolingTransformer | Epoch 999/1000 | Duration: 0.47s | Train Loss: 0.7941 | Val Loss: 0.9897 | LR: 0.000005
# Model MeanPoolingTransformer | Epoch 1000/1000 | Duration: 0.48s | Train Loss: 0.7890 | Val Loss: 0.9963 | LR: 0.000005

# %%
import matplotlib.pyplot as plt
from datetime import datetime

plt.figure(figsize=(12, 6))
plt.plot(train_losses, label='Train Loss')
plt.plot(val_losses, label='Validation Loss')
plt.xlabel('Epoch')
plt.ylabel('Loss')
plt.title('Training and Validation Loss Over Epochs')
plt.legend()
plt.grid()
if train_losses[-1] < 0.01:  # Check if the final train loss is low
    model_name = f"{model._get_name()}_{datetime.now().strftime('%Y%m%d_%H%M')}"
    model_file_path = f"../pytorch_checkpoints/{model_name}.pth"
    # os.makedirs(os.path.dirname(model_file_path), exist_ok=True)
    torch.save(model.state_dict(), model_file_path)
    print(f"Model saved to {model_file_path}")
    plt.savefig(f'../plots/loss_curves/{model_name}_loss.png')

plt.show()

# %% [markdown]
# # Testing Model with Zero State

# %%
def interleave_tensor_pqc_in_circuit(base_ops:list, qubits:int, blocks:int, pqc_gates:list, params:list):
    """Interleave PQC operations into the base circuit."""
    interleaved_circuit = []
    # print(params.shape)
    for i, op in enumerate(base_ops):
        # print(i, op)
        interleaved_circuit.append(op)
        if (i + 1) % blocks == 0:
            k = (i + 1) // blocks - 1
            # print(f"Interleaving PQC operations for block {k}")
            for q in range(qubits):
                for j, g in enumerate(pqc_gates):
                    # print(g, q, (k,q,j), params[k, q, j])
                    interleaved_circuit.append((g, [q], params[k, q, j].detach().numpy()))
    return interleaved_circuit

# %%
from jax_scripts.jax_noise import PennylaneNoisyGates
from jax_scripts.jax_simulate import run_circuit_with_noise_model
from jax_scripts.jax_loss import pure_state_fidelity

import jax.numpy as jnp

noise_model = PennylaneNoisyGates()
# NUM_QUBITS = 5
ZERO_STATE = jnp.zeros((2 ** NUM_QUBITS,), dtype=jnp.complex64).at[0].set(1.0)

circuit = raw_data[0]['base_circuit_tokens']  # Example circuit
pqc_circuit = raw_data[0]['pqc_circuit_tokens']  # Example PQC circuit

# %%
model.eval()  # Set the model to evaluation mode
net_fid_model = []
net_fid_default = []
for i, data in enumerate(raw_data):
    circuit = data['base_circuit_tokens']
    pqc_circuit = data['pqc_circuit_tokens']
    circuit_encoded = qc_tokenizer.encode(circuit, return_tensors='pt')
    model_inputs = {
        "input_ids": circuit_encoded["input_ids"].to(device),
        "attention_mask": circuit_encoded["attention_mask"].to(device),
    }
    pred_theta = model(**model_inputs).to('cpu')
    # pred_theta = sin_cos_to_angles(pred_theta).to('cpu')
    # print(pred_theta)
    # pred_theta = decode_von_mises_parameters(pred_params)['mean_angle_rad'].to(torch.device('cpu'))
    circuit_interleaved = interleave_tensor_pqc_in_circuit(circuit, NUM_QUBITS, GATE_BLOCKS, PQC_GATES, pred_theta)

    measured_modelPQC = run_circuit_with_noise_model(circuit_interleaved, ZERO_STATE, noise_model, NUM_QUBITS)
    measured_defaultPQC = run_circuit_with_noise_model(pqc_circuit, ZERO_STATE, noise_model, NUM_QUBITS)

    fidelity_modelPQC = pure_state_fidelity(ZERO_STATE, measured_modelPQC)
    fidelity_defaultPQC = pure_state_fidelity(ZERO_STATE, measured_defaultPQC)

    net_fid_model.append(fidelity_modelPQC)
    net_fid_default.append(fidelity_defaultPQC)

    # print(f"Fidelity (Model PQC): {fidelity_modelPQC:.4e}, Fidelity (Default PQC): {fidelity_defaultPQC:.4e}")

# %%
import numpy as np
print(f"Net Fidelity (Model PQC): {np.mean(net_fid_model):.4e}, Net Fidelity (Default PQC): {np.mean(net_fid_default):.4e}")
# Out:
# Net Fidelity (Model PQC): 3.1352e-02, Net Fidelity (Default PQC): 9.9145e-01

# %%
model.eval()  # Set the model to evaluation mode
test_fid_model = []
test_fid_default = []
for i, data in enumerate(qc_test_dataloader):

    tokens, params = data
    circuit_ops = qc_tokenizer.decode(tokens['input_ids'][0])
    circuit_ops = [(op[0], op[1], []) for op in circuit_ops]  # Add params placeholder from the circuit ops
    pqc_circuit = interleave_tensor_pqc_in_circuit(circuit_ops, NUM_QUBITS, GATE_BLOCKS, PQC_GATES, params[0])

    input_ids = tokens['input_ids'].to(device)
    attention_mask = tokens['attention_mask'].to(device)

    pred_theta = model(input_ids, attention_mask=attention_mask).to('cpu')[0]
    # pred_theta = sin_cos_to_angles(pred_theta).to('cpu')
    # print(pred_theta)
    # pred_theta = decode_von_mises_parameters(pred_params)['mean_angle_rad'].to(torch.device('cpu'))
    circuit_interleaved = interleave_tensor_pqc_in_circuit(circuit_ops, NUM_QUBITS, GATE_BLOCKS, PQC_GATES, pred_theta)

    measured_modelPQC = run_circuit_with_noise_model(circuit_interleaved, ZERO_STATE, noise_model, NUM_QUBITS)
    measured_defaultPQC = run_circuit_with_noise_model(pqc_circuit, ZERO_STATE, noise_model, NUM_QUBITS)

    fidelity_modelPQC = pure_state_fidelity(ZERO_STATE, measured_modelPQC)
    fidelity_defaultPQC = pure_state_fidelity(ZERO_STATE, measured_defaultPQC)

    test_fid_model.append(fidelity_modelPQC)
    test_fid_default.append(fidelity_defaultPQC)

    print(f"Fidelity (Model PQC): {fidelity_modelPQC:.4e}, Fidelity (Default PQC): {fidelity_defaultPQC:.4e}")
# Out:
# Fidelity (Model PQC): 1.1269e-02, Fidelity (Default PQC): 9.9341e-01
# Fidelity (Model PQC): 1.4584e-02, Fidelity (Default PQC): 9.9949e-01
# Fidelity (Model PQC): 2.4432e-02, Fidelity (Default PQC): 9.9938e-01
# Fidelity (Model PQC): 3.7016e-02, Fidelity (Default PQC): 9.7406e-01
# Fidelity (Model PQC): 3.3162e-03, Fidelity (Default PQC): 9.9944e-01
# Fidelity (Model PQC): 5.0366e-02, Fidelity (Default PQC): 9.9725e-01
# Fidelity (Model PQC): 8.1139e-03, Fidelity (Default PQC): 9.9976e-01
# Fidelity (Model PQC): 1.4670e-01, Fidelity (Default PQC): 9.9957e-01
# Fidelity (Model PQC): 1.2793e-01, Fidelity (Default PQC): 9.9894e-01
# Fidelity (Model PQC): 4.1848e-02, Fidelity (Default PQC): 9.8856e-01
# Fidelity (Model PQC): 3.3088e-02, Fidelity (Default PQC): 9.9810e-01
# Fidelity (Model PQC): 5.0110e-02, Fidelity (Default PQC): 9.9918e-01
# Fidelity (Model PQC): 3.3308e-02, Fidelity (Default PQC): 9.8865e-01
# Fidelity (Model PQC): 2.9598e-02, Fidelity (Default PQC): 9.9955e-01
# Fidelity (Model PQC): 1.3472e-01, Fidelity (Default PQC): 9.9933e-01
# Fidelity (Model PQC): 7.1458e-02, Fidelity (Default PQC): 9.7887e-01
# Fidelity (Model PQC): 2.6122e-02, Fidelity (Default PQC): 9.9917e-01
# Fidelity (Model PQC): 2.9790e-02, Fidelity (Default PQC): 9.9775e-01
# Fidelity (Model PQC): 1.6888e-02, Fidelity (Default PQC): 9.9841e-01
# Fidelity (Model PQC): 2.3473e-02, Fidelity (Default PQC): 9.9941e-01
# Fidelity (Model PQC): 4.3696e-02, Fidelity (Default PQC): 9.8810e-01
# Fidelity (Model PQC): 6.5221e-02, Fidelity (Default PQC): 9.9974e-01
# Fidelity (Model PQC): 5.6687e-03, Fidelity (Default PQC): 9.8862e-01
# Fidelity (Model PQC): 3.2700e-03, Fidelity (Default PQC): 9.5448e-01
# Fidelity (Model PQC): 3.1512e-02, Fidelity (Default PQC): 9.9798e-01
# Fidelity (Model PQC): 2.9132e-03, Fidelity (Default PQC): 9.9908e-01
# Fidelity (Model PQC): 3.3364e-02, Fidelity (Default PQC): 9.9709e-01
# Fidelity (Model PQC): 4.8497e-02, Fidelity (Default PQC): 9.9968e-01
# Fidelity (Model PQC): 6.8865e-02, Fidelity (Default PQC): 9.6391e-01
# Fidelity (Model PQC): 2.1790e-03, Fidelity (Default PQC): 9.9980e-01
# Fidelity (Model PQC): 2.0747e-02, Fidelity (Default PQC): 9.9946e-01
# Fidelity (Model PQC): 7.1266e-04, Fidelity (Default PQC): 9.8709e-01
# Fidelity (Model PQC): 1.7456e-02, Fidelity (Default PQC): 9.9950e-01
# Fidelity (Model PQC): 2.2791e-03, Fidelity (Default PQC): 9.8283e-01
# Fidelity (Model PQC): 1.4208e-02, Fidelity (Default PQC): 9.9187e-01
# Fidelity (Model PQC): 3.5276e-02, Fidelity (Default PQC): 9.8917e-01
# Fidelity (Model PQC): 1.1548e-02, Fidelity (Default PQC): 9.8986e-01
# Fidelity (Model PQC): 1.5769e-02, Fidelity (Default PQC): 9.9916e-01
# Fidelity (Model PQC): 4.5946e-03, Fidelity (Default PQC): 9.9961e-01
# Fidelity (Model PQC): 2.7401e-02, Fidelity (Default PQC): 9.9948e-01
# Fidelity (Model PQC): 8.0665e-03, Fidelity (Default PQC): 9.9952e-01
# Fidelity (Model PQC): 4.5497e-03, Fidelity (Default PQC): 9.9937e-01
# Fidelity (Model PQC): 6.8322e-02, Fidelity (Default PQC): 9.9880e-01
# Fidelity (Model PQC): 6.2549e-03, Fidelity (Default PQC): 9.8561e-01
# Fidelity (Model PQC): 3.1626e-02, Fidelity (Default PQC): 9.9508e-01
# Fidelity (Model PQC): 7.9446e-02, Fidelity (Default PQC): 9.9968e-01
# Fidelity (Model PQC): 1.5701e-02, Fidelity (Default PQC): 9.9968e-01
# Fidelity (Model PQC): 1.3252e-01, Fidelity (Default PQC): 9.9963e-01
# Fidelity (Model PQC): 2.5277e-02, Fidelity (Default PQC): 9.8784e-01
# Fidelity (Model PQC): 5.8881e-02, Fidelity (Default PQC): 9.8908e-01
# Fidelity (Model PQC): 4.6871e-03, Fidelity (Default PQC): 9.5302e-01
# Fidelity (Model PQC): 1.5133e-02, Fidelity (Default PQC): 9.8973e-01
# Fidelity (Model PQC): 1.1493e-02, Fidelity (Default PQC): 9.8668e-01
# Fidelity (Model PQC): 4.1510e-02, Fidelity (Default PQC): 9.9983e-01
# Fidelity (Model PQC): 2.3449e-02, Fidelity (Default PQC): 9.8560e-01
# Fidelity (Model PQC): 2.7925e-02, Fidelity (Default PQC): 9.7554e-01
# Fidelity (Model PQC): 2.8742e-02, Fidelity (Default PQC): 9.8625e-01
# Fidelity (Model PQC): 2.8702e-02, Fidelity (Default PQC): 9.9807e-01
# Fidelity (Model PQC): 1.6939e-02, Fidelity (Default PQC): 9.9971e-01
# Fidelity (Model PQC): 4.7454e-03, Fidelity (Default PQC): 9.5949e-01
# Fidelity (Model PQC): 5.1414e-02, Fidelity (Default PQC): 9.9921e-01
# Fidelity (Model PQC): 8.5728e-03, Fidelity (Default PQC): 9.9921e-01
# Fidelity (Model PQC): 4.9188e-02, Fidelity (Default PQC): 9.9921e-01
# Fidelity (Model PQC): 1.3282e-02, Fidelity (Default PQC): 9.9798e-01
# Fidelity (Model PQC): 2.2235e-02, Fidelity (Default PQC): 9.6084e-01
# Fidelity (Model PQC): 8.2482e-03, Fidelity (Default PQC): 9.9935e-01
# Fidelity (Model PQC): 1.7240e-02, Fidelity (Default PQC): 9.9055e-01
# Fidelity (Model PQC): 5.4614e-02, Fidelity (Default PQC): 9.8993e-01
# Fidelity (Model PQC): 1.7542e-02, Fidelity (Default PQC): 9.8834e-01
# Fidelity (Model PQC): 7.3666e-05, Fidelity (Default PQC): 9.9283e-01
# Fidelity (Model PQC): 1.7372e-01, Fidelity (Default PQC): 9.9957e-01
# Fidelity (Model PQC): 1.2432e-03, Fidelity (Default PQC): 9.9979e-01
# Fidelity (Model PQC): 6.5934e-02, Fidelity (Default PQC): 9.9978e-01
# Fidelity (Model PQC): 2.9834e-02, Fidelity (Default PQC): 9.9963e-01
# Fidelity (Model PQC): 5.4832e-02, Fidelity (Default PQC): 9.8756e-01
# Fidelity (Model PQC): 5.9623e-03, Fidelity (Default PQC): 9.9091e-01
# Fidelity (Model PQC): 1.2233e-02, Fidelity (Default PQC): 9.9387e-01
# Fidelity (Model PQC): 1.4343e-02, Fidelity (Default PQC): 9.8748e-01
# Fidelity (Model PQC): 5.7373e-03, Fidelity (Default PQC): 9.9974e-01
# Fidelity (Model PQC): 4.4299e-02, Fidelity (Default PQC): 9.9956e-01
# Fidelity (Model PQC): 2.6823e-02, Fidelity (Default PQC): 9.9790e-01
# Fidelity (Model PQC): 1.6342e-03, Fidelity (Default PQC): 9.9044e-01
# Fidelity (Model PQC): 4.2426e-02, Fidelity (Default PQC): 9.9955e-01
# Fidelity (Model PQC): 1.5742e-02, Fidelity (Default PQC): 9.7448e-01
# Fidelity (Model PQC): 3.1539e-02, Fidelity (Default PQC): 9.9956e-01
# Fidelity (Model PQC): 1.3040e-01, Fidelity (Default PQC): 9.9894e-01
# Fidelity (Model PQC): 2.8310e-02, Fidelity (Default PQC): 9.9888e-01
# Fidelity (Model PQC): 4.3557e-04, Fidelity (Default PQC): 9.8910e-01
# Fidelity (Model PQC): 2.6142e-02, Fidelity (Default PQC): 9.9949e-01
# Fidelity (Model PQC): 1.4749e-01, Fidelity (Default PQC): 9.9970e-01
# Fidelity (Model PQC): 1.9958e-02, Fidelity (Default PQC): 9.8631e-01
# Fidelity (Model PQC): 5.4341e-02, Fidelity (Default PQC): 9.9954e-01
# Fidelity (Model PQC): 4.4251e-02, Fidelity (Default PQC): 9.9933e-01
# Fidelity (Model PQC): 1.1302e-02, Fidelity (Default PQC): 9.9868e-01
# Fidelity (Model PQC): 6.5765e-02, Fidelity (Default PQC): 9.9862e-01
# Fidelity (Model PQC): 3.6191e-02, Fidelity (Default PQC): 9.9986e-01
# Fidelity (Model PQC): 4.0730e-03, Fidelity (Default PQC): 9.9928e-01
# Fidelity (Model PQC): 8.9010e-03, Fidelity (Default PQC): 9.5780e-01
# Fidelity (Model PQC): 9.9462e-05, Fidelity (Default PQC): 9.5364e-01
# Fidelity (Model PQC): 1.0423e-01, Fidelity (Default PQC): 9.9677e-01
# Fidelity (Model PQC): 1.3413e-02, Fidelity (Default PQC): 9.9986e-01
# Fidelity (Model PQC): 3.5397e-02, Fidelity (Default PQC): 9.9904e-01
# Fidelity (Model PQC): 1.3733e-02, Fidelity (Default PQC): 9.8856e-01
# Fidelity (Model PQC): 2.0940e-02, Fidelity (Default PQC): 9.9847e-01
# Fidelity (Model PQC): 3.3047e-03, Fidelity (Default PQC): 9.9902e-01
# Fidelity (Model PQC): 7.6439e-03, Fidelity (Default PQC): 9.9878e-01
# Fidelity (Model PQC): 2.4034e-02, Fidelity (Default PQC): 9.9888e-01
# Fidelity (Model PQC): 8.9486e-02, Fidelity (Default PQC): 9.9978e-01
# Fidelity (Model PQC): 3.7227e-02, Fidelity (Default PQC): 9.9910e-01
# Fidelity (Model PQC): 9.8230e-03, Fidelity (Default PQC): 9.9919e-01
# Fidelity (Model PQC): 5.4814e-02, Fidelity (Default PQC): 9.9981e-01
# Fidelity (Model PQC): 5.2005e-02, Fidelity (Default PQC): 9.6327e-01
# Fidelity (Model PQC): 1.0333e-02, Fidelity (Default PQC): 9.9918e-01
# Fidelity (Model PQC): 8.0861e-02, Fidelity (Default PQC): 9.9877e-01
# Fidelity (Model PQC): 1.0082e-01, Fidelity (Default PQC): 9.5474e-01
# Fidelity (Model PQC): 5.8142e-03, Fidelity (Default PQC): 9.9855e-01
# Fidelity (Model PQC): 8.1704e-02, Fidelity (Default PQC): 9.9961e-01
# Fidelity (Model PQC): 6.8842e-03, Fidelity (Default PQC): 9.9762e-01
# Fidelity (Model PQC): 1.5749e-02, Fidelity (Default PQC): 9.8797e-01
# Fidelity (Model PQC): 1.3091e-04, Fidelity (Default PQC): 9.9816e-01
# Fidelity (Model PQC): 6.8297e-03, Fidelity (Default PQC): 9.8066e-01
# Fidelity (Model PQC): 2.8318e-02, Fidelity (Default PQC): 9.9957e-01
# Fidelity (Model PQC): 4.4766e-03, Fidelity (Default PQC): 9.9914e-01
# Fidelity (Model PQC): 1.0605e-03, Fidelity (Default PQC): 9.9574e-01
# Fidelity (Model PQC): 3.2660e-02, Fidelity (Default PQC): 9.8775e-01
# Fidelity (Model PQC): 1.0470e-03, Fidelity (Default PQC): 9.8530e-01
# Fidelity (Model PQC): 5.3525e-02, Fidelity (Default PQC): 9.9973e-01
# Fidelity (Model PQC): 3.0575e-02, Fidelity (Default PQC): 9.9785e-01
# Fidelity (Model PQC): 3.8423e-02, Fidelity (Default PQC): 9.9951e-01
# Fidelity (Model PQC): 2.9620e-03, Fidelity (Default PQC): 9.9845e-01
# Fidelity (Model PQC): 2.4027e-03, Fidelity (Default PQC): 9.8746e-01
# Fidelity (Model PQC): 1.2223e-02, Fidelity (Default PQC): 9.7765e-01
# Fidelity (Model PQC): 1.0995e-02, Fidelity (Default PQC): 9.9939e-01
# Fidelity (Model PQC): 1.0070e-01, Fidelity (Default PQC): 9.9973e-01
# Fidelity (Model PQC): 3.1094e-03, Fidelity (Default PQC): 9.8906e-01
# Fidelity (Model PQC): 5.6653e-02, Fidelity (Default PQC): 9.9924e-01
# Fidelity (Model PQC): 1.3371e-03, Fidelity (Default PQC): 9.9971e-01
# Fidelity (Model PQC): 1.8927e-03, Fidelity (Default PQC): 9.2042e-01
# Fidelity (Model PQC): 1.5097e-01, Fidelity (Default PQC): 9.9966e-01
# Fidelity (Model PQC): 4.3164e-02, Fidelity (Default PQC): 9.7487e-01
# Fidelity (Model PQC): 8.2478e-02, Fidelity (Default PQC): 9.7961e-01
# Fidelity (Model PQC): 4.2083e-04, Fidelity (Default PQC): 9.9981e-01
# Fidelity (Model PQC): 5.3322e-03, Fidelity (Default PQC): 9.6314e-01
# Fidelity (Model PQC): 1.8410e-02, Fidelity (Default PQC): 9.8706e-01
# Fidelity (Model PQC): 2.1730e-02, Fidelity (Default PQC): 9.8906e-01
# Fidelity (Model PQC): 4.4314e-04, Fidelity (Default PQC): 9.8526e-01
# Fidelity (Model PQC): 3.5752e-04, Fidelity (Default PQC): 9.9884e-01
# Fidelity (Model PQC): 6.6360e-03, Fidelity (Default PQC): 9.9882e-01
# Fidelity (Model PQC): 3.8908e-03, Fidelity (Default PQC): 9.9887e-01
# Fidelity (Model PQC): 4.7492e-03, Fidelity (Default PQC): 9.9012e-01
# Fidelity (Model PQC): 2.0539e-02, Fidelity (Default PQC): 9.5125e-01
# Fidelity (Model PQC): 1.1682e-01, Fidelity (Default PQC): 9.9907e-01
# Fidelity (Model PQC): 2.6360e-02, Fidelity (Default PQC): 9.9091e-01
# Fidelity (Model PQC): 1.3461e-01, Fidelity (Default PQC): 9.8805e-01
# Fidelity (Model PQC): 5.1476e-03, Fidelity (Default PQC): 9.5623e-01
# Fidelity (Model PQC): 3.0185e-03, Fidelity (Default PQC): 9.9882e-01
# Fidelity (Model PQC): 3.5709e-03, Fidelity (Default PQC): 9.9977e-01
# Fidelity (Model PQC): 1.4756e-02, Fidelity (Default PQC): 9.8902e-01
# Fidelity (Model PQC): 8.0677e-02, Fidelity (Default PQC): 9.9967e-01
# Fidelity (Model PQC): 1.2432e-01, Fidelity (Default PQC): 9.9971e-01
# Fidelity (Model PQC): 6.4308e-03, Fidelity (Default PQC): 9.8812e-01
# Fidelity (Model PQC): 1.2960e-02, Fidelity (Default PQC): 9.8915e-01
# Fidelity (Model PQC): 8.1099e-02, Fidelity (Default PQC): 9.8864e-01
# Fidelity (Model PQC): 1.4852e-03, Fidelity (Default PQC): 9.9952e-01
# Fidelity (Model PQC): 4.4752e-03, Fidelity (Default PQC): 9.9230e-01
# Fidelity (Model PQC): 5.2187e-03, Fidelity (Default PQC): 9.8944e-01
# Fidelity (Model PQC): 3.3074e-02, Fidelity (Default PQC): 9.9907e-01
# Fidelity (Model PQC): 1.0604e-01, Fidelity (Default PQC): 9.9936e-01
# Fidelity (Model PQC): 1.1764e-02, Fidelity (Default PQC): 9.9966e-01
# Fidelity (Model PQC): 7.0521e-02, Fidelity (Default PQC): 9.7809e-01
# Fidelity (Model PQC): 2.1850e-02, Fidelity (Default PQC): 9.8506e-01
# Fidelity (Model PQC): 1.2189e-02, Fidelity (Default PQC): 9.8615e-01
# Fidelity (Model PQC): 2.4169e-02, Fidelity (Default PQC): 9.9957e-01
# Fidelity (Model PQC): 8.7062e-04, Fidelity (Default PQC): 9.8869e-01
# Fidelity (Model PQC): 7.2713e-02, Fidelity (Default PQC): 9.8754e-01

# %%
print(f"Net Fidelity (Model PQC): {np.mean(test_fid_model):.4e}, Net Fidelity (Default PQC): {np.mean(test_fid_default):.4e}")
# Out:
# Net Fidelity (Model PQC): 3.3374e-02, Net Fidelity (Default PQC): 9.9165e-01
